# %%
import pandas as pd
import numpy as np 
from sklearn.cluster import KMeans
import pulp

# %%
import zipfile
import os

# Define the path to the uploaded zip file
zip_path = r"C:\Users\gudal\Downloads\optimal ambualance  Datasets.zip"
extract_path = "extracted_data"

# Extract the zip file
with zipfile.ZipFile(zip_path, 'r') as zip_ref:
    zip_ref.extractall(extract_path)

# List extracted files
extracted_files = []
for root, dirs, files in os.walk(extract_path):
    for file in files:
        extracted_files.append(os.path.join(root, file))

extracted_files
# Out:
# ['extracted_data\\accidents.csv',
#  'extracted_data\\accidents2.csv',
#  'extracted_data\\class_data.csv',
#  'extracted_data\\combined_dataset.csv',
#  'extracted_data\\final.csv']

# %%
import pandas as pd
df = pd.read_csv(r"C:\Users\gudal\Downloads\ambulace optimization\extracted_data\final.csv")
accident_df = df[df['class'] == 1].copy()
accident_coords = accident_df[['latitude', 'longitude']].values

# %%
num_stations = 100
kmeans = KMeans(n_clusters=num_stations, random_state=42)
kmeans.fit(accident_coords)
station_coords = kmeans.cluster_centers_

# %%
def haversine(lat1, lon1, lat2, lon2):
    R = 6371  # Radius of Earth in km
    lat1, lon1, lat2, lon2 = map(np.radians, [lat1, lon1, lat2, lon2])
    dlat, dlon = lat2 - lat1, lon2 - lon1
    a = np.sin(dlat/2)**2 + np.cos(lat1) * np.cos(lat2) * np.sin(dlon/2)**2
    return R * 2 * np.arcsin(np.sqrt(a))

# Approx travel time in minutes
avg_speed_kmph = 40
num_accidents = len(accident_df)
travel_time = np.zeros((num_stations, num_accidents))

for i, (s_lat, s_lon) in enumerate(station_coords):
    for j, (a_lat, a_lon) in enumerate(accident_coords):
        dist_km = haversine(s_lat, s_lon, a_lat, a_lon)
        travel_time[i][j] = (dist_km / avg_speed_kmph) * 60

# %%
model = pulp.LpProblem("Ambulance_Placement", pulp.LpMinimize)

# Decision Variables
x = pulp.LpVariable.dicts("PlaceAmbulance", range(num_stations), cat='Binary')  # whether ambulance is placed
y = pulp.LpVariable.dicts("Assign", [(i, j) for i in range(num_stations) for j in range(num_accidents)], cat='Binary')

# Objective: Minimize total travel time
model += pulp.lpSum([travel_time[i][j] * y[(i, j)] for i in range(num_stations) for j in range(num_accidents)])

# Constraint: Total number of ambulances
max_ambulances = 100
model += pulp.lpSum([x[i] for i in range(num_stations)]) == max_ambulances, "MaxAmbulances"

# Constraint: Each accident is served by exactly one station
for j in range(num_accidents):
    model += pulp.lpSum([y[(i, j)] for i in range(num_stations)]) == 1, f"ServeAccident_{j}"


# Constraint: Assignments only if ambulance is placed
for i in range(num_stations):
    for j in range(num_accidents):
        model += y[(i, j)] <= x[i], f"Link_{i}_{j}"

# Constraint: Each station can serve only up to its capacity
station_capacity = 100  # Can be customized per station
for i in range(num_stations):
    model += pulp.lpSum([y[(i, j)] for j in range(num_accidents)]) <= station_capacity, f"Capacity_{i}"

# %%
model.solve()
print("Status:", pulp.LpStatus[model.status])
# Out:
# Status: Optimal

# %%
print("\n Ambulances Placed At:")
for i in range(num_stations):
    if x[i].varValue == 1:
        lat, lon = station_coords[i]
        print(f" - Station {i} at (lat: {lat:.5f}, lon: {lon:.5f})")
# Out:
#  Ambulances Placed At:
#  - Station 0 at (lat: -1.26276, lon: 36.84029)
#  - Station 1 at (lat: -2.07988, lon: 37.47302)
#  - Station 2 at (lat: -1.17987, lon: 36.93493)
#  - Station 3 at (lat: -1.35571, lon: 36.90750)
#  - Station 4 at (lat: -0.98387, lon: 36.63075)
#  - Station 5 at (lat: -1.02935, lon: 37.06862)
#  - Station 6 at (lat: -1.26153, lon: 36.71980)
#  - Station 7 at (lat: -1.31867, lon: 36.80603)
#  - Station 8 at (lat: -1.52452, lon: 37.12514)
#  - Station 9 at (lat: -2.10000, lon: 36.75000)
#  - Station 10 at (lat: -2.66757, lon: 37.87949)
#  - Station 11 at (lat: -0.90640, lon: 37.70654)
#  - Station 12 at (lat: -0.59498, lon: 36.98525)
#  - Station 13 at (lat: -1.27468, lon: 37.29636)
#  - Station 14 at (lat: -1.25888, lon: 36.77866)
#  - Station 15 at (lat: -1.33024, lon: 36.88628)
#  - Station 16 at (lat: -1.12069, lon: 37.00396)
#  - Station 17 at (lat: -1.24114, lon: 36.68669)
#  - Station 18 at (lat: -1.42951, lon: 37.64657)
#  - Station 19 at (lat: -1.23007, lon: 36.87815)
#  - Station 20 at (lat: -2.54716, lon: 36.78737)
#  - Station 21 at (lat: -1.14938, lon: 36.66697)
#  - Station 22 at (lat: -1.48316, lon: 36.95737)
#  - Station 23 at (lat: -1.39062, lon: 36.75905)
#  - Station 24 at (lat: -1.32254, lon: 36.84329)
#  - Station 25 at (lat: -1.28408, lon: 36.82493)
#  - Station 26 at (lat: -0.61960, lon: 37.18489)
#  - Station 27 at (lat: -1.28341, lon: 36.96066)
#  - Station 28 at (lat: -1.42412, lon: 36.95579)
#  - Station 29 at (lat: -2.92557, lon: 37.51421)
#  - Station 30 at (lat: -0.82043, lon: 37.05026)
#  - Station 31 at (lat: -1.32722, lon: 36.69223)
#  - Station 32 at (lat: -0.90186, lon: 37.18700)
#  - Station 33 at (lat: -1.47069, lon: 37.34468)
#  - Station 34 at (lat: -1.14679, lon: 37.52331)
#  - Station 35 at (lat: -1.21107, lon: 36.83749)
#  - Station 36 at (lat: -1.48575, lon: 37.05353)
#  - Station 37 at (lat: -1.15380, lon: 36.96360)
#  - Station 38 at (lat: -2.39482, lon: 37.53934)
#  - Station 39 at (lat: -0.90384, lon: 36.97361)
#  - Station 40 at (lat: -1.29548, lon: 36.87917)
#  - Station 41 at (lat: -1.20271, lon: 36.91606)
#  - Station 42 at (lat: -1.23172, lon: 36.80246)
#  - Station 43 at (lat: -1.29438, lon: 36.78761)
#  - Station 44 at (lat: -1.21849, lon: 36.89345)
#  - Station 45 at (lat: -1.06422, lon: 37.05218)
#  - Station 46 at (lat: -1.77911, lon: 36.82161)
#  - Station 47 at (lat: -1.28154, lon: 37.12967)
#  - Station 48 at (lat: -0.88323, lon: 36.57629)
#  - Station 49 at (lat: -1.74096, lon: 37.12903)
#  - Station 50 at (lat: -1.26325, lon: 36.76095)
#  - Station 51 at (lat: -1.26887, lon: 36.80644)
#  - Station 52 at (lat: -1.05117, lon: 36.33220)
#  - Station 53 at (lat: -1.34965, lon: 36.76290)
#  - Station 54 at (lat: -0.69010, lon: 36.97830)
#  - Station 55 at (lat: -1.95983, lon: 37.12617)
#  - Station 56 at (lat: -1.11540, lon: 36.62222)
#  - Station 57 at (lat: -1.26902, lon: 36.90127)
#  - Station 58 at (lat: -1.30430, lon: 36.82737)
#  - Station 59 at (lat: -0.94949, lon: 36.60148)
#  - Station 60 at (lat: -1.20684, lon: 36.78138)
#  - Station 61 at (lat: -1.25452, lon: 36.85542)
#  - Station 62 at (lat: -1.32012, lon: 36.89708)
#  - Station 63 at (lat: -1.37483, lon: 36.92321)
#  - Station 64 at (lat: -3.05000, lon: 37.75000)
#  - Station 65 at (lat: -1.09748, lon: 37.02243)
#  - Station 66 at (lat: -1.29016, lon: 36.74477)
#  - Station 67 at (lat: -0.90000, lon: 36.81667)
#  - Station 68 at (lat: -1.34860, lon: 37.37898)
#  - Station 69 at (lat: -1.00729, lon: 36.73544)
#  - Station 70 at (lat: -1.23002, lon: 36.66537)
#  - Station 71 at (lat: -1.04894, lon: 37.09902)
#  - Station 72 at (lat: -1.26811, lon: 36.99967)
#  - Station 73 at (lat: -1.00732, lon: 36.90481)
#  - Station 74 at (lat: -2.15787, lon: 37.60769)
#  - Station 75 at (lat: -1.53165, lon: 37.27016)
#  - Station 76 at (lat: -0.67774, lon: 37.19063)
#  - Station 77 at (lat: -1.11008, lon: 36.83237)
#  - Station 78 at (lat: -1.44030, lon: 36.70013)
#  - Station 79 at (lat: -1.05619, lon: 37.03238)
#  - Station 80 at (lat: -1.29276, lon: 36.85162)
#  - Station 81 at (lat: -1.39402, lon: 36.94092)
#  - Station 82 at (lat: -1.44827, lon: 36.98608)
#  - Station 83 at (lat: -1.24731, lon: 36.86963)
#  - Station 84 at (lat: -1.16816, lon: 36.82619)
#  - Station 85 at (lat: -1.29478, lon: 36.80726)
#  - Station 86 at (lat: -1.32977, lon: 36.86556)
#  - Station 87 at (lat: -1.31547, lon: 36.72522)
#  - Station 88 at (lat: -1.26125, lon: 36.69477)
#  - Station 89 at (lat: -1.24870, lon: 36.81804)
#  - Station 90 at (lat: -1.37806, lon: 36.67690)
#  - Station 91 at (lat: -0.67268, lon: 36.81587)
#  - Station 92 at (lat: -1.32503, lon: 36.78359)
#  - Station 93 at (lat: -1.26377, lon: 36.74601)
#  - Station 94 at (lat: -0.91137, lon: 37.82129)
#  - Station 95 at (lat: -2.13887, lon: 37.38084)
#  - Station 96 at (lat: -2.01646, lon: 37.37752)
#  - Station 97 at (lat: -1.31854, lon: 36.92437)
#  - Station 98 at (lat: -1.20490, lon: 37.01233)
#  - Station 99 at (lat: -1.29548, lon: 36.76836)

# %%
print("\n Accident Assignments:")
for j in range(num_accidents):
    for i in range(num_stations):
        if y[(i, j)].varValue == 1:
            print(f" - Accident {j} handled by Station {i}")
# Out:
#  Accident Assignments:
#  - Accident 0 handled by Station 16
#  - Accident 1 handled by Station 76
#  - Accident 2 handled by Station 76
#  - Accident 3 handled by Station 85
#  - Accident 4 handled by Station 16
#  - Accident 5 handled by Station 76
#  - Accident 6 handled by Station 16
#  - Accident 7 handled by Station 92
#  - Accident 8 handled by Station 77
#  - Accident 9 handled by Station 65
#  - Accident 10 handled by Station 25
#  - Accident 11 handled by Station 89
#  - Accident 12 handled by Station 8
#  - Accident 13 handled by Station 90
#  - Accident 14 handled by Station 62
#  - Accident 15 handled by Station 22
#  - Accident 16 handled by Station 57
#  - Accident 17 handled by Station 70
#  - Accident 18 handled by Station 57
#  - Accident 19 handled by Station 70
#  - Accident 20 handled by Station 57
#  - Accident 21 handled by Station 73
#  - Accident 22 handled by Station 63
#  - Accident 23 handled by Station 63
#  - Accident 24 handled by Station 58
#  - Accident 25 handled by Station 8
#  - Accident 26 handled by Station 86
#  - Accident 27 handled by Station 87
#  - Accident 28 handled by Station 99
#  - Accident 29 handled by Station 99
#  - Accident 30 handled by Station 79
#  - Accident 31 handled by Station 43
#  - Accident 32 handled by Station 16
#  - Accident 33 handled by Station 65
#  - Accident 34 handled by Station 79
#  - Accident 35 handled by Station 21
#  - Accident 36 handled by Station 62
#  - Accident 37 handled by Station 83
#  - Accident 38 handled by Station 19
#  - Accident 39 handled by Station 60
#  - Accident 40 handled by Station 3
#  - Accident 41 handled by Station 86
#  - Accident 42 handled by Station 90
#  - Accident 43 handled by Station 33
#  - Accident 44 handled by Station 90
#  - Accident 45 handled by Station 3
#  - Accident 46 handled by Station 37
#  - Accident 47 handled by Station 62
#  - Accident 48 handled by Station 62
#  - Accident 49 handled by Station 24
#  - Accident 50 handled by Station 24
#  - Accident 51 handled by Station 23
#  - Accident 52 handled by Station 52
#  - Accident 53 handled by Station 40
#  - Accident 54 handled by Station 40
#  - Accident 55 handled by Station 98
#  - Accident 56 handled by Station 17
#  - Accident 57 handled by Station 5
#  - Accident 58 handled by Station 5
#  - Accident 59 handled by Station 35
#  - Accident 60 handled by Station 78
#  - Accident 61 handled by Station 19
#  - Accident 62 handled by Station 81
#  - Accident 63 handled by Station 78
#  - Accident 64 handled by Station 88
#  - Accident 65 handled by Station 53
#  - Accident 66 handled by Station 57
#  - Accident 67 handled by Station 50
#  - Accident 68 handled by Station 50
#  - Accident 69 handled by Station 21
#  - Accident 70 handled by Station 6
#  - Accident 71 handled by Station 27
#  - Accident 72 handled by Station 23
#  - Accident 73 handled by Station 65
#  - Accident 74 handled by Station 71
#  - Accident 75 handled by Station 41
#  - Accident 76 handled by Station 50
#  - Accident 77 handled by Station 50
#  - Accident 78 handled by Station 16
#  - Accident 79 handled by Station 16
#  - Accident 80 handled by Station 41
#  - Accident 81 handled by Station 2
#  - Accident 82 handled by Station 16
#  - Accident 83 handled by Station 98
#  - Accident 84 handled by Station 98
#  - Accident 85 handled by Station 7
#  - Accident 86 handled by Station 56
#  - Accident 87 handled by Station 25
#  - Accident 88 handled by Station 87
#  - Accident 89 handled by Station 37
#  - Accident 90 handled by Station 37
#  - Accident 91 handled by Station 37
#  - Accident 92 handled by Station 37
#  - Accident 93 handled by Station 37
#  - Accident 94 handled by Station 37
#  - Accident 95 handled by Station 37
#  - Accident 96 handled by Station 79
#  - Accident 97 handled by Station 14
#  - Accident 98 handled by Station 92
#  - Accident 99 handled by Station 82
#  - Accident 100 handled by Station 24
#  - Accident 101 handled by Station 24
#  - Accident 102 handled by Station 90
#  - Accident 103 handled by Station 35
#  - Accident 104 handled by Station 28
#  - Accident 105 handled by Station 86
#  - Accident 106 handled by Station 62
#  - Accident 107 handled by Station 84
#  - Accident 108 handled by Station 15
#  - Accident 109 handled by Station 87
#  - Accident 110 handled by Station 62
#  - Accident 111 handled by Station 83
#  - Accident 112 handled by Station 15
#  - Accident 113 handled by Station 15
#  - Accident 114 handled by Station 15
#  - Accident 115 handled by Station 15
#  - Accident 116 handled by Station 36
#  - Accident 117 handled by Station 25
#  - Accident 118 handled by Station 43
#  - Accident 119 handled by Station 25
#  - Accident 120 handled by Station 99
#  - Accident 121 handled by Station 44
#  - Accident 122 handled by Station 44
#  - Accident 123 handled by Station 98
#  - Accident 124 handled by Station 66
#  - Accident 125 handled by Station 25
#  - Accident 126 handled by Station 78
#  - Accident 127 handled by Station 59
#  - Accident 128 handled by Station 4
#  - Accident 129 handled by Station 59
#  - Accident 130 handled by Station 40
#  - Accident 131 handled by Station 40
#  - Accident 132 handled by Station 88
#  - Accident 133 handled by Station 59
#  - Accident 134 handled by Station 25
#  - Accident 135 handled by Station 59
#  - Accident 136 handled by Station 85
#  - Accident 137 handled by Station 27
#  - Accident 138 handled by Station 14
#  - Accident 139 handled by Station 92
#  - Accident 140 handled by Station 85
#  - Accident 141 handled by Station 85
#  - Accident 142 handled by Station 27
#  - Accident 143 handled by Station 75
#  - Accident 144 handled by Station 63
#  - Accident 145 handled by Station 37
#  - Accident 146 handled by Station 79
#  - Accident 147 handled by Station 14
#  - Accident 148 handled by Station 14
#  - Accident 149 handled by Station 16
#  - Accident 150 handled by Station 19
#  - Accident 151 handled by Station 19
#  - Accident 152 handled by Station 19
#  - Accident 153 handled by Station 19
#  - Accident 154 handled by Station 19
#  - Accident 155 handled by Station 19
#  - Accident 156 handled by Station 86
#  - Accident 157 handled by Station 42
#  - Accident 158 handled by Station 58
#  - Accident 159 handled by Station 73
#  - Accident 160 handled by Station 73
#  - Accident 161 handled by Station 98
#  - Accident 162 handled by Station 62
#  - Accident 163 handled by Station 62
#  - Accident 164 handled by Station 81
#  - Accident 165 handled by Station 99
#  - Accident 166 handled by Station 57
#  - Accident 167 handled by Station 99
#  - Accident 168 handled by Station 0
#  - Accident 169 handled by Station 5
#  - Accident 170 handled by Station 92
#  - Accident 171 handled by Station 15
#  - Accident 172 handled by Station 14
#  - Accident 173 handled by Station 21
#  - Accident 174 handled by Station 98
#  - Accident 175 handled by Station 80
#  - Accident 176 handled by Station 40
#  - Accident 177 handled by Station 40
#  - Accident 178 handled by Station 90
#  - Accident 179 handled by Station 72
#  - Accident 180 handled by Station 92
#  - Accident 181 handled by Station 7
#  - Accident 182 handled by Station 51
#  - Accident 183 handled by Station 76
#  - Accident 184 handled by Station 2
#  - Accident 185 handled by Station 41
#  - Accident 186 handled by Station 44
#  - Accident 187 handled by Station 72
#  - Accident 188 handled by Station 44
#  - Accident 189 handled by Station 73
#  - Accident 190 handled by Station 73
#  - Accident 191 handled by Station 73
#  - Accident 192 handled by Station 73
#  - Accident 193 handled by Station 41
#  - Accident 194 handled by Station 41
#  - Accident 195 handled by Station 73
#  - Accident 196 handled by Station 99
#  - Accident 197 handled by Station 45
#  - Accident 198 handled by Station 45
#  - Accident 199 handled by Station 53
#  - Accident 200 handled by Station 50
#  - Accident 201 handled by Station 50
#  - Accident 202 handled by Station 0
#  - Accident 203 handled by Station 2
#  - Accident 204 handled by Station 31
#  - Accident 205 handled by Station 90
#  - Accident 206 handled by Station 99
#  - Accident 207 handled by Station 63
#  - Accident 208 handled by Station 63
#  - Accident 209 handled by Station 92
#  - Accident 210 handled by Station 16
#  - Accident 211 handled by Station 6
#  - Accident 212 handled by Station 93
#  - Accident 213 handled by Station 28
#  - Accident 214 handled by Station 6
#  - Accident 215 handled by Station 93
#  - Accident 216 handled by Station 6
#  - Accident 217 handled by Station 93
#  - Accident 218 handled by Station 6
#  - Accident 219 handled by Station 6
#  - Accident 220 handled by Station 84
#  - Accident 221 handled by Station 8
#  - Accident 222 handled by Station 30
#  - Accident 223 handled by Station 56
#  - Accident 224 handled by Station 43
#  - Accident 225 handled by Station 15
#  - Accident 226 handled by Station 80
#  - Accident 227 handled by Station 15
#  - Accident 228 handled by Station 62
#  - Accident 229 handled by Station 36
#  - Accident 230 handled by Station 16
#  - Accident 231 handled by Station 62
#  - Accident 232 handled by Station 62
#  - Accident 233 handled by Station 15
#  - Accident 234 handled by Station 8
#  - Accident 235 handled by Station 57
#  - Accident 236 handled by Station 14
#  - Accident 237 handled by Station 17
#  - Accident 238 handled by Station 62
#  - Accident 239 handled by Station 43
#  - Accident 240 handled by Station 6
#  - Accident 241 handled by Station 60
#  - Accident 242 handled by Station 60
#  - Accident 243 handled by Station 93
#  - Accident 244 handled by Station 93
#  - Accident 245 handled by Station 87
#  - Accident 246 handled by Station 35
#  - Accident 247 handled by Station 57
#  - Accident 248 handled by Station 6
#  - Accident 249 handled by Station 16
#  - Accident 250 handled by Station 16
#  - Accident 251 handled by Station 16
#  - Accident 252 handled by Station 15
#  - Accident 253 handled by Station 16
#  - Accident 254 handled by Station 83
#  - Accident 255 handled by Station 7
#  - Accident 256 handled by Station 7
#  - Accident 257 handled by Station 88
#  - Accident 258 handled by Station 77
#  - Accident 259 handled by Station 87
#  - Accident 260 handled by Station 88
#  - Accident 261 handled by Station 99
#  - Accident 262 handled by Station 5
#  - Accident 263 handled by Station 86
#  - Accident 264 handled by Station 73
#  - Accident 265 handled by Station 16
#  - Accident 266 handled by Station 87
#  - Accident 267 handled by Station 83
#  - Accident 268 handled by Station 7
#  - Accident 269 handled by Station 72
#  - Accident 270 handled by Station 87
#  - Accident 271 handled by Station 88
#  - Accident 272 handled by Station 77
#  - Accident 273 handled by Station 43
#  - Accident 274 handled by Station 16
#  - Accident 275 handled by Station 88
#  - Accident 276 handled by Station 99
#  - Accident 277 handled by Station 5
#  - Accident 278 handled by Station 86
#  - Accident 279 handled by Station 73
#  - Accident 280 handled by Station 71
#  - Accident 281 handled by Station 87
#  - Accident 282 handled by Station 57
#  - Accident 283 handled by Station 28
#  - Accident 284 handled by Station 87
#  - Accident 285 handled by Station 28
#  - Accident 286 handled by Station 81
#  - Accident 287 handled by Station 3
#  - Accident 288 handled by Station 19
#  - Accident 289 handled by Station 88
#  - Accident 290 handled by Station 88
#  - Accident 291 handled by Station 73
#  - Accident 292 handled by Station 15
#  - Accident 293 handled by Station 37
#  - Accident 294 handled by Station 37
#  - Accident 295 handled by Station 37
#  - Accident 296 handled by Station 72
#  - Accident 297 handled by Station 60
#  - Accident 298 handled by Station 82
#  - Accident 299 handled by Station 60
#  - Accident 300 handled by Station 58
#  - Accident 301 handled by Station 84
#  - Accident 302 handled by Station 57
#  - Accident 303 handled by Station 66
#  - Accident 304 handled by Station 14
#  - Accident 305 handled by Station 50
#  - Accident 306 handled by Station 78
#  - Accident 307 handled by Station 78
#  - Accident 308 handled by Station 5
#  - Accident 309 handled by Station 45
#  - Accident 310 handled by Station 27
#  - Accident 311 handled by Station 78
#  - Accident 312 handled by Station 89
#  - Accident 313 handled by Station 27
#  - Accident 314 handled by Station 27
#  - Accident 315 handled by Station 27
#  - Accident 316 handled by Station 92
#  - Accident 317 handled by Station 80
#  - Accident 318 handled by Station 27
#  - Accident 319 handled by Station 99
#  - Accident 320 handled by Station 23
#  - Accident 321 handled by Station 7
#  - Accident 322 handled by Station 84
#  - Accident 323 handled by Station 40
#  - Accident 324 handled by Station 40
#  - Accident 325 handled by Station 21
#  - Accident 326 handled by Station 27
#  - Accident 327 handled by Station 27
#  - Accident 328 handled by Station 87
#  - Accident 329 handled by Station 31
#  - Accident 330 handled by Station 73
#  - Accident 331 handled by Station 89
#  - Accident 332 handled by Station 72
#  - Accident 333 handled by Station 66
#  - Accident 334 handled by Station 66
#  - Accident 335 handled by Station 0
#  - Accident 336 handled by Station 83
#  - Accident 337 handled by Station 83
#  - Accident 338 handled by Station 83
#  - Accident 339 handled by Station 83
#  - Accident 340 handled by Station 25
#  - Accident 341 handled by Station 72
#  - Accident 342 handled by Station 66
#  - Accident 343 handled by Station 51
#  - Accident 344 handled by Station 51
#  - Accident 345 handled by Station 19
#  - Accident 346 handled by Station 51
#  - Accident 347 handled by Station 86
#  - Accident 348 handled by Station 19
#  - Accident 349 handled by Station 40
#  - Accident 350 handled by Station 40
#  - Accident 351 handled by Station 24
#  - Accident 352 handled by Station 42
#  - Accident 353 handled by Station 17
#  - Accident 354 handled by Station 37
#  - Accident 355 handled by Station 56
#  - Accident 356 handled by Station 89
#  - Accident 357 handled by Station 97
#  - Accident 358 handled by Station 97
#  - Accident 359 handled by Station 97
#  - Accident 360 handled by Station 97
#  - Accident 361 handled by Station 99
#  - Accident 362 handled by Station 99
#  - Accident 363 handled by Station 42
#  - Accident 364 handled by Station 15
#  - Accident 365 handled by Station 2
#  - Accident 366 handled by Station 70
#  - Accident 367 handled by Station 2
#  - Accident 368 handled by Station 2
#  - Accident 369 handled by Station 84
#  - Accident 370 handled by Station 84
#  - Accident 371 handled by Station 99
#  - Accident 372 handled by Station 83
#  - Accident 373 handled by Station 83
#  - Accident 374 handled by Station 58
#  - Accident 375 handled by Station 19
#  - Accident 376 handled by Station 19
#  - Accident 377 handled by Station 56
#  - Accident 378 handled by Station 28
#  - Accident 379 handled by Station 6
#  - Accident 380 handled by Station 72
#  - Accident 381 handled by Station 36
#  - Accident 382 handled by Station 24
#  - Accident 383 handled by Station 98
#  - Accident 384 handled by Station 19
#  - Accident 385 handled by Station 19
#  - Accident 386 handled by Station 43
#  - Accident 387 handled by Station 27
#  - Accident 388 handled by Station 79
#  - Accident 389 handled by Station 79
#  - Accident 390 handled by Station 3
#  - Accident 391 handled by Station 39
#  - Accident 392 handled by Station 41
#  - Accident 393 handled by Station 15
#  - Accident 394 handled by Station 17
#  - Accident 395 handled by Station 70
#  - Accident 396 handled by Station 57
#  - Accident 397 handled by Station 43
#  - Accident 398 handled by Station 15
#  - Accident 399 handled by Station 45
#  - Accident 400 handled by Station 45
#  - Accident 401 handled by Station 77
#  - Accident 402 handled by Station 84
#  - Accident 403 handled by Station 84
#  - Accident 404 handled by Station 61
#  - Accident 405 handled by Station 84
#  - Accident 406 handled by Station 61
#  - Accident 407 handled by Station 82
#  - Accident 408 handled by Station 84
#  - Accident 409 handled by Station 84
#  - Accident 410 handled by Station 61
#  - Accident 411 handled by Station 61
#  - Accident 412 handled by Station 57
#  - Accident 413 handled by Station 5
#  - Accident 414 handled by Station 43
#  - Accident 415 handled by Station 73
#  - Accident 416 handled by Station 92
#  - Accident 417 handled by Station 90
#  - Accident 418 handled by Station 15
#  - Accident 419 handled by Station 78
#  - Accident 420 handled by Station 97
#  - Accident 421 handled by Station 21
#  - Accident 422 handled by Station 73
#  - Accident 423 handled by Station 73
#  - Accident 424 handled by Station 73
#  - Accident 425 handled by Station 57
#  - Accident 426 handled by Station 66
#  - Accident 427 handled by Station 82
#  - Accident 428 handled by Station 14
#  - Accident 429 handled by Station 22
#  - Accident 430 handled by Station 43
#  - Accident 431 handled by Station 43
#  - Accident 432 handled by Station 51
#  - Accident 433 handled by Station 43
#  - Accident 434 handled by Station 99
#  - Accident 435 handled by Station 99
#  - Accident 436 handled by Station 85
#  - Accident 437 handled by Station 99
#  - Accident 438 handled by Station 92
#  - Accident 439 handled by Station 23
#  - Accident 440 handled by Station 99
#  - Accident 441 handled by Station 43
#  - Accident 442 handled by Station 85
#  - Accident 443 handled by Station 23
#  - Accident 444 handled by Station 90
#  - Accident 445 handled by Station 43
#  - Accident 446 handled by Station 82
#  - Accident 447 handled by Station 85
#  - Accident 448 handled by Station 15
#  - Accident 449 handled by Station 72
#  - Accident 450 handled by Station 72
#  - Accident 451 handled by Station 15
#  - Accident 452 handled by Station 15
#  - Accident 453 handled by Station 62
#  - Accident 454 handled by Station 15
#  - Accident 455 handled by Station 15
#  - Accident 456 handled by Station 15
#  - Accident 457 handled by Station 85
#  - Accident 458 handled by Station 82
#  - Accident 459 handled by Station 43
#  - Accident 460 handled by Station 99
#  - Accident 461 handled by Station 99
#  - Accident 462 handled by Station 98
#  - Accident 463 handled by Station 41
#  - Accident 464 handled by Station 66
#  - Accident 465 handled by Station 92
#  - Accident 466 handled by Station 66
#  - Accident 467 handled by Station 36
#  - Accident 468 handled by Station 7
#  - Accident 469 handled by Station 27
#  - Accident 470 handled by Station 92
#  - Accident 471 handled by Station 62
#  - Accident 472 handled by Station 81
#  - Accident 473 handled by Station 57
#  - Accident 474 handled by Station 27
#  - Accident 475 handled by Station 6
#  - Accident 476 handled by Station 92
#  - Accident 477 handled by Station 5
#  - Accident 478 handled by Station 27
#  - Accident 479 handled by Station 40
#  - Accident 480 handled by Station 80
#  - Accident 481 handled by Station 81
#  - Accident 482 handled by Station 81
#  - Accident 483 handled by Station 81
#  - Accident 484 handled by Station 57
#  - Accident 485 handled by Station 81
#  - Accident 486 handled by Station 63
#  - Accident 487 handled by Station 63
#  - Accident 488 handled by Station 81
#  - Accident 489 handled by Station 63
#  - Accident 490 handled by Station 81
#  - Accident 491 handled by Station 82
#  - Accident 492 handled by Station 72
#  - Accident 493 handled by Station 83
#  - Accident 494 handled by Station 16
#  - Accident 495 handled by Station 2
#  - Accident 496 handled by Station 83
#  - Accident 497 handled by Station 63
#  - Accident 498 handled by Station 98
#  - Accident 499 handled by Station 73
#  - Accident 500 handled by Station 5
#  - Accident 501 handled by Station 19
#  - Accident 502 handled by Station 73
#  - Accident 503 handled by Station 77
#  - Accident 504 handled by Station 79
#  - Accident 505 handled by Station 16
#  - Accident 506 handled by Station 70
#  - Accident 507 handled by Station 60
#  - Accident 508 handled by Station 83
#  - Accident 509 handled by Station 42
#  - Accident 510 handled by Station 2
#  - Accident 511 handled by Station 2
#  - Accident 512 handled by Station 43
#  - Accident 513 handled by Station 15
#  - Accident 514 handled by Station 73
#  - Accident 515 handled by Station 15
#  - Accident 516 handled by Station 83
#  - Accident 517 handled by Station 77
#  - Accident 518 handled by Station 36
#  - Accident 519 handled by Station 83
#  - Accident 520 handled by Station 77
#  - Accident 521 handled by Station 83
#  - Accident 522 handled by Station 79
#  - Accident 523 handled by Station 83
#  - Accident 524 handled by Station 59
#  - Accident 525 handled by Station 57
#  - Accident 526 handled by Station 93
#  - Accident 527 handled by Station 6
#  - Accident 528 handled by Station 80
#  - Accident 529 handled by Station 41
#  - Accident 530 handled by Station 98
#  - Accident 531 handled by Station 19
#  - Accident 532 handled by Station 61
#  - Accident 533 handled by Station 60
#  - Accident 534 handled by Station 21
#  - Accident 535 handled by Station 82
#  - Accident 536 handled by Station 78
#  - Accident 537 handled by Station 92
#  - Accident 538 handled by Station 0
#  - Accident 539 handled by Station 19
#  - Accident 540 handled by Station 99
#  - Accident 541 handled by Station 21
#  - Accident 542 handled by Station 6
#  - Accident 543 handled by Station 78
#  - Accident 544 handled by Station 66
#  - Accident 545 handled by Station 66
#  - Accident 546 handled by Station 16
#  - Accident 547 handled by Station 25
#  - Accident 548 handled by Station 57
#  - Accident 549 handled by Station 57
#  - Accident 550 handled by Station 16
#  - Accident 551 handled by Station 42
#  - Accident 552 handled by Station 51
#  - Accident 553 handled by Station 22
#  - Accident 554 handled by Station 82
#  - Accident 555 handled by Station 28
#  - Accident 556 handled by Station 3
#  - Accident 557 handled by Station 50
#  - Accident 558 handled by Station 50
#  - Accident 559 handled by Station 50
#  - Accident 560 handled by Station 93
#  - Accident 561 handled by Station 99
#  - Accident 562 handled by Station 3
#  - Accident 563 handled by Station 3
#  - Accident 564 handled by Station 3
#  - Accident 565 handled by Station 42
#  - Accident 566 handled by Station 23
#  - Accident 567 handled by Station 3
#  - Accident 568 handled by Station 97
#  - Accident 569 handled by Station 81
#  - Accident 570 handled by Station 45
#  - Accident 571 handled by Station 99
#  - Accident 572 handled by Station 45
#  - Accident 573 handled by Station 16
#  - Accident 574 handled by Station 41
#  - Accident 575 handled by Station 5
#  - Accident 576 handled by Station 40
#  - Accident 577 handled by Station 73
#  - Accident 578 handled by Station 98
#  - Accident 579 handled by Station 65
#  - Accident 580 handled by Station 65
#  - Accident 581 handled by Station 65
#  - Accident 582 handled by Station 65
#  - Accident 583 handled by Station 65
#  - Accident 584 handled by Station 65
#  - Accident 585 handled by Station 86
#  - Accident 586 handled by Station 65
#  - Accident 587 handled by Station 57
#  - Accident 588 handled by Station 63
#  - Accident 589 handled by Station 24
#  - Accident 590 handled by Station 28
#  - Accident 591 handled by Station 37
#  - Accident 592 handled by Station 31
#  - Accident 593 handled by Station 80
#  - Accident 594 handled by Station 21
#  - Accident 595 handled by Station 21
#  - Accident 596 handled by Station 51
#  - Accident 597 handled by Station 63
#  - Accident 598 handled by Station 21
#  - Accident 599 handled by Station 21
#  - Accident 600 handled by Station 73
#  - Accident 601 handled by Station 79
#  - Accident 602 handled by Station 71
#  - Accident 603 handled by Station 79
#  - Accident 604 handled by Station 79
#  - Accident 605 handled by Station 79
#  - Accident 606 handled by Station 89
#  - Accident 607 handled by Station 79
#  - Accident 608 handled by Station 65
#  - Accident 609 handled by Station 70
#  - Accident 610 handled by Station 73
#  - Accident 611 handled by Station 90
#  - Accident 612 handled by Station 42
#  - Accident 613 handled by Station 42
#  - Accident 614 handled by Station 76
#  - Accident 615 handled by Station 27
#  - Accident 616 handled by Station 72
#  - Accident 617 handled by Station 16
#  - Accident 618 handled by Station 73
#  - Accident 619 handled by Station 73
#  - Accident 620 handled by Station 35
#  - Accident 621 handled by Station 3
#  - Accident 622 handled by Station 22
#  - Accident 623 handled by Station 22
#  - Accident 624 handled by Station 56
#  - Accident 625 handled by Station 22
#  - Accident 626 handled by Station 24
#  - Accident 627 handled by Station 98
#  - Accident 628 handled by Station 97
#  - Accident 629 handled by Station 81
#  - Accident 630 handled by Station 81
#  - Accident 631 handled by Station 86
#  - Accident 632 handled by Station 86
#  - Accident 633 handled by Station 81
#  - Accident 634 handled by Station 81
#  - Accident 635 handled by Station 81
#  - Accident 636 handled by Station 92
#  - Accident 637 handled by Station 80
#  - Accident 638 handled by Station 66
#  - Accident 639 handled by Station 51
#  - Accident 640 handled by Station 80
#  - Accident 641 handled by Station 53
#  - Accident 642 handled by Station 63
#  - Accident 643 handled by Station 40
#  - Accident 644 handled by Station 63
#  - Accident 645 handled by Station 89
#  - Accident 646 handled by Station 82
#  - Accident 647 handled by Station 42
#  - Accident 648 handled by Station 40
#  - Accident 649 handled by Station 27
#  - Accident 650 handled by Station 84
#  - Accident 651 handled by Station 84
#  - Accident 652 handled by Station 84
#  - Accident 653 handled by Station 84
#  - Accident 654 handled by Station 77
#  - Accident 655 handled by Station 84
#  - Accident 656 handled by Station 99
#  - Accident 657 handled by Station 84
#  - Accident 658 handled by Station 84
#  - Accident 659 handled by Station 84
#  - Accident 660 handled by Station 88
#  - Accident 661 handled by Station 88
#  - Accident 662 handled by Station 88
#  - Accident 663 handled by Station 84
#  - Accident 664 handled by Station 72
#  - Accident 665 handled by Station 72
#  - Accident 666 handled by Station 81
#  - Accident 667 handled by Station 86
#  - Accident 668 handled by Station 35
#  - Accident 669 handled by Station 85
#  - Accident 670 handled by Station 89
#  - Accident 671 handled by Station 24
#  - Accident 672 handled by Station 41
#  - Accident 673 handled by Station 83
#  - Accident 674 handled by Station 61
#  - Accident 675 handled by Station 21
#  - Accident 676 handled by Station 57
#  - Accident 677 handled by Station 77
#  - Accident 678 handled by Station 99
#  - Accident 679 handled by Station 88
#  - Accident 680 handled by Station 85
#  - Accident 681 handled by Station 42
#  - Accident 682 handled by Station 77
#  - Accident 683 handled by Station 0
#  - Accident 684 handled by Station 6
#  - Accident 685 handled by Station 14
#  - Accident 686 handled by Station 80
#  - Accident 687 handled by Station 80
#  - Accident 688 handled by Station 92
#  - Accident 689 handled by Station 73
#  - Accident 690 handled by Station 73
#  - Accident 691 handled by Station 66
#  - Accident 692 handled by Station 78
#  - Accident 693 handled by Station 14
#  - Accident 694 handled by Station 25
#  - Accident 695 handled by Station 36
#  - Accident 696 handled by Station 25
#  - Accident 697 handled by Station 70
#  - Accident 698 handled by Station 70
#  - Accident 699 handled by Station 70
#  - Accident 700 handled by Station 5
#  - Accident 701 handled by Station 70
#  - Accident 702 handled by Station 25
#  - Accident 703 handled by Station 25
#  - Accident 704 handled by Station 41
#  - Accident 705 handled by Station 27
#  - Accident 706 handled by Station 32
#  - Accident 707 handled by Station 41
#  - Accident 708 handled by Station 84
#  - Accident 709 handled by Station 89
#  - Accident 710 handled by Station 3
#  - Accident 711 handled by Station 15
#  - Accident 712 handled by Station 23
#  - Accident 713 handled by Station 15
#  - Accident 714 handled by Station 62
#  - Accident 715 handled by Station 51
#  - Accident 716 handled by Station 51
#  - Accident 717 handled by Station 51
#  - Accident 718 handled by Station 87
#  - Accident 719 handled by Station 43
#  - Accident 720 handled by Station 86
#  - Accident 721 handled by Station 90
#  - Accident 722 handled by Station 36
#  - Accident 723 handled by Station 85
#  - Accident 724 handled by Station 90
#  - Accident 725 handled by Station 80
#  - Accident 726 handled by Station 72
#  - Accident 727 handled by Station 66
#  - Accident 728 handled by Station 13
#  - Accident 729 handled by Station 80
#  - Accident 730 handled by Station 80
#  - Accident 731 handled by Station 47
#  - Accident 732 handled by Station 23
#  - Accident 733 handled by Station 38
#  - Accident 734 handled by Station 36
#  - Accident 735 handled by Station 66
#  - Accident 736 handled by Station 80
#  - Accident 737 handled by Station 42
#  - Accident 738 handled by Station 72
#  - Accident 739 handled by Station 31
#  - Accident 740 handled by Station 80
#  - Accident 741 handled by Station 80
#  - Accident 742 handled by Station 69
#  - Accident 743 handled by Station 21
#  - Accident 744 handled by Station 47
#  - Accident 745 handled by Station 23
#  - Accident 746 handled by Station 37
#  - Accident 747 handled by Station 37
#  - Accident 748 handled by Station 37
#  - Accident 749 handled by Station 77
#  - Accident 750 handled by Station 77
#  - Accident 751 handled by Station 59
#  - Accident 752 handled by Station 31
#  - Accident 753 handled by Station 21
#  - Accident 754 handled by Station 37
#  - Accident 755 handled by Station 37
#  - Accident 756 handled by Station 37
#  - Accident 757 handled by Station 77
#  - Accident 758 handled by Station 77
#  - Accident 759 handled by Station 59
#  - Accident 760 handled by Station 98
#  - Accident 761 handled by Station 19
#  - Accident 762 handled by Station 73
#  - Accident 763 handled by Station 73
#  - Accident 764 handled by Station 19
#  - Accident 765 handled by Station 19
#  - Accident 766 handled by Station 66
#  - Accident 767 handled by Station 27
#  - Accident 768 handled by Station 73
#  - Accident 769 handled by Station 8
#  - Accident 770 handled by Station 53
#  - Accident 771 handled by Station 73
#  - Accident 772 handled by Station 15
#  - Accident 773 handled by Station 42
#  - Accident 774 handled by Station 6
#  - Accident 775 handled by Station 61
#  - Accident 776 handled by Station 72
#  - Accident 777 handled by Station 51
#  - Accident 778 handled by Station 99
#  - Accident 779 handled by Station 19
#  - Accident 780 handled by Station 51
#  - Accident 781 handled by Station 19
#  - Accident 782 handled by Station 42
#  - Accident 783 handled by Station 6
#  - Accident 784 handled by Station 37
#  - Accident 785 handled by Station 50
#  - Accident 786 handled by Station 98
#  - Accident 787 handled by Station 21
#  - Accident 788 handled by Station 16
#  - Accident 789 handled by Station 83
#  - Accident 790 handled by Station 21
#  - Accident 791 handled by Station 31
#  - Accident 792 handled by Station 45
#  - Accident 793 handled by Station 45
#  - Accident 794 handled by Station 14
#  - Accident 795 handled by Station 72
#  - Accident 796 handled by Station 17
#  - Accident 797 handled by Station 37
#  - Accident 798 handled by Station 65
#  - Accident 799 handled by Station 0
#  - Accident 800 handled by Station 37
#  - Accident 801 handled by Station 41
#  - Accident 802 handled by Station 98
#  - Accident 803 handled by Station 37
#  - Accident 804 handled by Station 44
#  - Accident 805 handled by Station 7
#  - Accident 806 handled by Station 7
#  - Accident 807 handled by Station 90
#  - Accident 808 handled by Station 44
#  - Accident 809 handled by Station 78
#  - Accident 810 handled by Station 43
#  - Accident 811 handled by Station 44
#  - Accident 812 handled by Station 57
#  - Accident 813 handled by Station 25
#  - Accident 814 handled by Station 57
#  - Accident 815 handled by Station 57
#  - Accident 816 handled by Station 66
#  - Accident 817 handled by Station 16
#  - Accident 818 handled by Station 16
#  - Accident 819 handled by Station 87
#  - Accident 820 handled by Station 90
#  - Accident 821 handled by Station 15
#  - Accident 822 handled by Station 15
#  - Accident 823 handled by Station 40
#  - Accident 824 handled by Station 66
#  - Accident 825 handled by Station 53
#  - Accident 826 handled by Station 97
#  - Accident 827 handled by Station 96
#  - Accident 828 handled by Station 1
#  - Accident 829 handled by Station 66
#  - Accident 830 handled by Station 15
#  - Accident 831 handled by Station 1
#  - Accident 832 handled by Station 80
#  - Accident 833 handled by Station 1
#  - Accident 834 handled by Station 24
#  - Accident 835 handled by Station 21
#  - Accident 836 handled by Station 1
#  - Accident 837 handled by Station 36
#  - Accident 838 handled by Station 2
#  - Accident 839 handled by Station 1
#  - Accident 840 handled by Station 53
#  - Accident 841 handled by Station 28
#  - Accident 842 handled by Station 92
#  - Accident 843 handled by Station 0
#  - Accident 844 handled by Station 70
#  - Accident 845 handled by Station 84
#  - Accident 846 handled by Station 83
#  - Accident 847 handled by Station 53
#  - Accident 848 handled by Station 66
#  - Accident 849 handled by Station 97
#  - Accident 850 handled by Station 83
#  - Accident 851 handled by Station 83
#  - Accident 852 handled by Station 25
#  - Accident 853 handled by Station 83
#  - Accident 854 handled by Station 28
#  - Accident 855 handled by Station 85
#  - Accident 856 handled by Station 88
#  - Accident 857 handled by Station 85
#  - Accident 858 handled by Station 85
#  - Accident 859 handled by Station 85
#  - Accident 860 handled by Station 31
#  - Accident 861 handled by Station 85
#  - Accident 862 handled by Station 92
#  - Accident 863 handled by Station 92
#  - Accident 864 handled by Station 92
#  - Accident 865 handled by Station 43
#  - Accident 866 handled by Station 65
#  - Accident 867 handled by Station 65
#  - Accident 868 handled by Station 85
#  - Accident 869 handled by Station 87
#  - Accident 870 handled by Station 58
#  - Accident 871 handled by Station 85
#  - Accident 872 handled by Station 21
#  - Accident 873 handled by Station 97
#  - Accident 874 handled by Station 99
#  - Accident 875 handled by Station 7
#  - Accident 876 handled by Station 81
#  - Accident 877 handled by Station 84
#  - Accident 878 handled by Station 14
#  - Accident 879 handled by Station 21
#  - Accident 880 handled by Station 14
#  - Accident 881 handled by Station 98
#  - Accident 882 handled by Station 73
#  - Accident 883 handled by Station 40
#  - Accident 884 handled by Station 27
#  - Accident 885 handled by Station 93
#  - Accident 886 handled by Station 17
#  - Accident 887 handled by Station 88
#  - Accident 888 handled by Station 6
#  - Accident 889 handled by Station 93
#  - Accident 890 handled by Station 93
#  - Accident 891 handled by Station 6
#  - Accident 892 handled by Station 93
#  - Accident 893 handled by Station 93
#  - Accident 894 handled by Station 93
#  - Accident 895 handled by Station 93
#  - Accident 896 handled by Station 17
#  - Accident 897 handled by Station 85
#  - Accident 898 handled by Station 92
#  - Accident 899 handled by Station 90
#  - Accident 900 handled by Station 0
#  - Accident 901 handled by Station 92
#  - Accident 902 handled by Station 70
#  - Accident 903 handled by Station 19
#  - Accident 904 handled by Station 19
#  - Accident 905 handled by Station 19
#  - Accident 906 handled by Station 14
#  - Accident 907 handled by Station 98
#  - Accident 908 handled by Station 19
#  - Accident 909 handled by Station 19
#  - Accident 910 handled by Station 25
#  - Accident 911 handled by Station 70
#  - Accident 912 handled by Station 97
#  - Accident 913 handled by Station 82
#  - Accident 914 handled by Station 97
#  - Accident 915 handled by Station 44
#  - Accident 916 handled by Station 44
#  - Accident 917 handled by Station 41
#  - Accident 918 handled by Station 44
#  - Accident 919 handled by Station 41
#  - Accident 920 handled by Station 50
#  - Accident 921 handled by Station 51
#  - Accident 922 handled by Station 42
#  - Accident 923 handled by Station 42
#  - Accident 924 handled by Station 42
#  - Accident 925 handled by Station 78
#  - Accident 926 handled by Station 78
#  - Accident 927 handled by Station 78
#  - Accident 928 handled by Station 78
#  - Accident 929 handled by Station 43
#  - Accident 930 handled by Station 78
#  - Accident 931 handled by Station 57
#  - Accident 932 handled by Station 35
#  - Accident 933 handled by Station 35
#  - Accident 934 handled by Station 0
#  - Accident 935 handled by Station 84
#  - Accident 936 handled by Station 84
#  - Accident 937 handled by Station 97
#  - Accident 938 handled by Station 62
#  - Accident 939 handled by Station 15
#  - Accident 940 handled by Station 15
#  - Accident 941 handled by Station 15
#  - Accident 942 handled by Station 3
#  - Accident 943 handled by Station 62
#  - Accident 944 handled by Station 15
#  - Accident 945 handled by Station 3
#  - Accident 946 handled by Station 3
#  - Accident 947 handled by Station 15
#  - Accident 948 handled by Station 3
#  - Accident 949 handled by Station 3
#  - Accident 950 handled by Station 3
#  - Accident 951 handled by Station 86
#  - Accident 952 handled by Station 62
#  - Accident 953 handled by Station 24
#  - Accident 954 handled by Station 77
#  - Accident 955 handled by Station 17
#  - Accident 956 handled by Station 41
#  - Accident 957 handled by Station 2
#  - Accident 958 handled by Station 44
#  - Accident 959 handled by Station 41
#  - Accident 960 handled by Station 15
#  - Accident 961 handled by Station 50
#  - Accident 962 handled by Station 21
#  - Accident 963 handled by Station 50
#  - Accident 964 handled by Station 83
#  - Accident 965 handled by Station 79
#  - Accident 966 handled by Station 63
#  - Accident 967 handled by Station 61
#  - Accident 968 handled by Station 27
#  - Accident 969 handled by Station 62
#  - Accident 970 handled by Station 27
#  - Accident 971 handled by Station 61
#  - Accident 972 handled by Station 62
#  - Accident 973 handled by Station 97
#  - Accident 974 handled by Station 97
#  - Accident 975 handled by Station 83
#  - Accident 976 handled by Station 27
#  - Accident 977 handled by Station 50
#  - Accident 978 handled by Station 41
#  - Accident 979 handled by Station 2
#  - Accident 980 handled by Station 41
#  - Accident 981 handled by Station 21
#  - Accident 982 handled by Station 50
#  - Accident 983 handled by Station 81
#  - Accident 984 handled by Station 79
#  - Accident 985 handled by Station 63
#  - Accident 986 handled by Station 80
#  - Accident 987 handled by Station 80
#  - Accident 988 handled by Station 61
#  - Accident 989 handled by Station 27
#  - Accident 990 handled by Station 62
#  - Accident 991 handled by Station 27
#  - Accident 992 handled by Station 62
#  - Accident 993 handled by Station 97
#  - Accident 994 handled by Station 97
#  - Accident 995 handled by Station 27
#  - Accident 996 handled by Station 35
#  - Accident 997 handled by Station 84
#  - Accident 998 handled by Station 79
#  - Accident 999 handled by Station 80
#  - Accident 1000 handled by Station 80
#  - Accident 1001 handled by Station 32
#  - Accident 1002 handled by Station 32
#  - Accident 1003 handled by Station 82
#  - Accident 1004 handled by Station 99
#  - Accident 1005 handled by Station 57
#  - Accident 1006 handled by Station 57
#  - Accident 1007 handled by Station 81
#  - Accident 1008 handled by Station 98
#  - Accident 1009 handled by Station 35
#  - Accident 1010 handled by Station 0
#  - Accident 1011 handled by Station 79
#  - Accident 1012 handled by Station 50
#  - Accident 1013 handled by Station 31
#  - Accident 1014 handled by Station 99
#  - Accident 1015 handled by Station 99
#  - Accident 1016 handled by Station 99
#  - Accident 1017 handled by Station 5
#  - Accident 1018 handled by Station 7
#  - Accident 1019 handled by Station 35
#  - Accident 1020 handled by Station 50
#  - Accident 1021 handled by Station 44
#  - Accident 1022 handled by Station 80
#  - Accident 1023 handled by Station 80
#  - Accident 1024 handled by Station 60
#  - Accident 1025 handled by Station 7
#  - Accident 1026 handled by Station 6
#  - Accident 1027 handled by Station 22
#  - Accident 1028 handled by Station 97
#  - Accident 1029 handled by Station 15
#  - Accident 1030 handled by Station 3
#  - Accident 1031 handled by Station 22
#  - Accident 1032 handled by Station 70
#  - Accident 1033 handled by Station 40
#  - Accident 1034 handled by Station 40
#  - Accident 1035 handled by Station 40
#  - Accident 1036 handled by Station 40
#  - Accident 1037 handled by Station 40
#  - Accident 1038 handled by Station 40
#  - Accident 1039 handled by Station 40
#  - Accident 1040 handled by Station 40
#  - Accident 1041 handled by Station 40
#  - Accident 1042 handled by Station 40
#  - Accident 1043 handled by Station 81
#  - Accident 1044 handled by Station 65
#  - Accident 1045 handled by Station 88
#  - Accident 1046 handled by Station 98
#  - Accident 1047 handled by Station 28
#  - Accident 1048 handled by Station 79
#  - Accident 1049 handled by Station 80
#  - Accident 1050 handled by Station 58
#  - Accident 1051 handled by Station 8
#  - Accident 1052 handled by Station 58
#  - Accident 1053 handled by Station 40
#  - Accident 1054 handled by Station 36
#  - Accident 1055 handled by Station 37
#  - Accident 1056 handled by Station 40
#  - Accident 1057 handled by Station 40
#  - Accident 1058 handled by Station 83
#  - Accident 1059 handled by Station 77
#  - Accident 1060 handled by Station 83
#  - Accident 1061 handled by Station 77
#  - Accident 1062 handled by Station 40
#  - Accident 1063 handled by Station 40
#  - Accident 1064 handled by Station 90
#  - Accident 1065 handled by Station 43
#  - Accident 1066 handled by Station 31
#  - Accident 1067 handled by Station 83
#  - Accident 1068 handled by Station 83
#  - Accident 1069 handled by Station 84
#  - Accident 1070 handled by Station 40
#  - Accident 1071 handled by Station 40
#  - Accident 1072 handled by Station 31
#  - Accident 1073 handled by Station 40
#  - Accident 1074 handled by Station 40
#  - Accident 1075 handled by Station 40
#  - Accident 1076 handled by Station 16
#  - Accident 1077 handled by Station 79
#  - Accident 1078 handled by Station 97
#  - Accident 1079 handled by Station 40
#  - Accident 1080 handled by Station 14
#  - Accident 1081 handled by Station 23
#  - Accident 1082 handled by Station 23
#  - Accident 1083 handled by Station 84
#  - Accident 1084 handled by Station 0
#  - Accident 1085 handled by Station 35
#  - Accident 1086 handled by Station 84
#  - Accident 1087 handled by Station 84
#  - Accident 1088 handled by Station 84
#  - Accident 1089 handled by Station 44
#  - Accident 1090 handled by Station 77
#  - Accident 1091 handled by Station 25
#  - Accident 1092 handled by Station 25
#  - Accident 1093 handled by Station 21
#  - Accident 1094 handled by Station 2
#  - Accident 1095 handled by Station 79
#  - Accident 1096 handled by Station 42
#  - Accident 1097 handled by Station 19
#  - Accident 1098 handled by Station 53
#  - Accident 1099 handled by Station 53
#  - Accident 1100 handled by Station 44
#  - Accident 1101 handled by Station 31
#  - Accident 1102 handled by Station 41
#  - Accident 1103 handled by Station 41
#  - Accident 1104 handled by Station 41
#  - Accident 1105 handled by Station 2
#  - Accident 1106 handled by Station 2
#  - Accident 1107 handled by Station 24
#  - Accident 1108 handled by Station 2
#  - Accident 1109 handled by Station 73
#  - Accident 1110 handled by Station 37
#  - Accident 1111 handled by Station 37
#  - Accident 1112 handled by Station 16
#  - Accident 1113 handled by Station 22
#  - Accident 1114 handled by Station 40
#  - Accident 1115 handled by Station 60
#  - Accident 1116 handled by Station 21
#  - Accident 1117 handled by Station 25
#  - Accident 1118 handled by Station 37
#  - Accident 1119 handled by Station 57
#  - Accident 1120 handled by Station 78
#  - Accident 1121 handled by Station 28
#  - Accident 1122 handled by Station 93
#  - Accident 1123 handled by Station 93
#  - Accident 1124 handled by Station 6
#  - Accident 1125 handled by Station 17
#  - Accident 1126 handled by Station 1
#  - Accident 1127 handled by Station 93
#  - Accident 1128 handled by Station 56
#  - Accident 1129 handled by Station 56
#  - Accident 1130 handled by Station 93
#  - Accident 1131 handled by Station 16
#  - Accident 1132 handled by Station 1
#  - Accident 1133 handled by Station 35
#  - Accident 1134 handled by Station 84
#  - Accident 1135 handled by Station 35
#  - Accident 1136 handled by Station 84
#  - Accident 1137 handled by Station 22
#  - Accident 1138 handled by Station 24
#  - Accident 1139 handled by Station 57
#  - Accident 1140 handled by Station 97
#  - Accident 1141 handled by Station 66
#  - Accident 1142 handled by Station 87
#  - Accident 1143 handled by Station 86
#  - Accident 1144 handled by Station 28
#  - Accident 1145 handled by Station 62
#  - Accident 1146 handled by Station 83
#  - Accident 1147 handled by Station 70
#  - Accident 1148 handled by Station 84
#  - Accident 1149 handled by Station 66
#  - Accident 1150 handled by Station 42
#  - Accident 1151 handled by Station 65
#  - Accident 1152 handled by Station 99
#  - Accident 1153 handled by Station 89
#  - Accident 1154 handled by Station 40
#  - Accident 1155 handled by Station 83
#  - Accident 1156 handled by Station 80
#  - Accident 1157 handled by Station 99
#  - Accident 1158 handled by Station 21
#  - Accident 1159 handled by Station 21
#  - Accident 1160 handled by Station 47
#  - Accident 1161 handled by Station 37
#  - Accident 1162 handled by Station 84
#  - Accident 1163 handled by Station 97
#  - Accident 1164 handled by Station 97
#  - Accident 1165 handled by Station 97
#  - Accident 1166 handled by Station 80
#  - Accident 1167 handled by Station 80
#  - Accident 1168 handled by Station 66
#  - Accident 1169 handled by Station 85
#  - Accident 1170 handled by Station 86
#  - Accident 1171 handled by Station 97
#  - Accident 1172 handled by Station 35
#  - Accident 1173 handled by Station 87
#  - Accident 1174 handled by Station 36
#  - Accident 1175 handled by Station 60
#  - Accident 1176 handled by Station 60
#  - Accident 1177 handled by Station 41
#  - Accident 1178 handled by Station 23
#  - Accident 1179 handled by Station 23
#  - Accident 1180 handled by Station 62
#  - Accident 1181 handled by Station 99
#  - Accident 1182 handled by Station 60
#  - Accident 1183 handled by Station 60
#  - Accident 1184 handled by Station 92
#  - Accident 1185 handled by Station 15
#  - Accident 1186 handled by Station 88
#  - Accident 1187 handled by Station 40
#  - Accident 1188 handled by Station 28
#  - Accident 1189 handled by Station 28
#  - Accident 1190 handled by Station 71
#  - Accident 1191 handled by Station 89
#  - Accident 1192 handled by Station 53
#  - Accident 1193 handled by Station 97
#  - Accident 1194 handled by Station 89
#  - Accident 1195 handled by Station 81
#  - Accident 1196 handled by Station 51
#  - Accident 1197 handled by Station 60
#  - Accident 1198 handled by Station 87
#  - Accident 1199 handled by Station 87
#  - Accident 1200 handled by Station 81
#  - Accident 1201 handled by Station 44
#  - Accident 1202 handled by Station 72
#  - Accident 1203 handled by Station 81
#  - Accident 1204 handled by Station 22
#  - Accident 1205 handled by Station 3
#  - Accident 1206 handled by Station 81
#  - Accident 1207 handled by Station 51
#  - Accident 1208 handled by Station 87
#  - Accident 1209 handled by Station 81
#  - Accident 1210 handled by Station 3
#  - Accident 1211 handled by Station 81
#  - Accident 1212 handled by Station 83
#  - Accident 1213 handled by Station 78
#  - Accident 1214 handled by Station 97
#  - Accident 1215 handled by Station 97
#  - Accident 1216 handled by Station 54
#  - Accident 1217 handled by Station 35
#  - Accident 1218 handled by Station 80
#  - Accident 1219 handled by Station 83
#  - Accident 1220 handled by Station 0
#  - Accident 1221 handled by Station 78
#  - Accident 1222 handled by Station 15
#  - Accident 1223 handled by Station 54
#  - Accident 1224 handled by Station 35
#  - Accident 1225 handled by Station 80
#  - Accident 1226 handled by Station 0
#  - Accident 1227 handled by Station 80
#  - Accident 1228 handled by Station 6
#  - Accident 1229 handled by Station 80
#  - Accident 1230 handled by Station 23
#  - Accident 1231 handled by Station 27
#  - Accident 1232 handled by Station 27
#  - Accident 1233 handled by Station 90
#  - Accident 1234 handled by Station 99
#  - Accident 1235 handled by Station 85
#  - Accident 1236 handled by Station 16
#  - Accident 1237 handled by Station 99
#  - Accident 1238 handled by Station 72
#  - Accident 1239 handled by Station 97
#  - Accident 1240 handled by Station 97
#  - Accident 1241 handled by Station 44
#  - Accident 1242 handled by Station 23
#  - Accident 1243 handled by Station 0
#  - Accident 1244 handled by Station 28
#  - Accident 1245 handled by Station 15
#  - Accident 1246 handled by Station 84
#  - Accident 1247 handled by Station 24
#  - Accident 1248 handled by Station 81
#  - Accident 1249 handled by Station 81
#  - Accident 1250 handled by Station 81
#  - Accident 1251 handled by Station 97
#  - Accident 1252 handled by Station 63
#  - Accident 1253 handled by Station 99
#  - Accident 1254 handled by Station 70
#  - Accident 1255 handled by Station 81
#  - Accident 1256 handled by Station 81
#  - Accident 1257 handled by Station 81
#  - Accident 1258 handled by Station 56
#  - Accident 1259 handled by Station 81
#  - Accident 1260 handled by Station 27
# ...
#  - Accident 5907 handled by Station 19
#  - Accident 5908 handled by Station 66
#  - Accident 5909 handled by Station 23
#  - Accident 5910 handled by Station 25
#  - Accident 5911 handled by Station 80
#  - Accident 5912 handled by Station 56
#  - Accident 5913 handled by Station 56
#  - Accident 5914 handled by Station 43
#  - Accident 5915 handled by Station 87
#  - Accident 5916 handled by Station 72
#  - Accident 5917 handled by Station 16
#  - Accident 5918 handled by Station 81
#  - Accident 5919 handled by Station 79
#  - Accident 5920 handled by Station 90
#  - Accident 5921 handled by Station 90
#  - Accident 5922 handled by Station 90
#  - Accident 5923 handled by Station 78
#  - Accident 5924 handled by Station 22
#  - Accident 5925 handled by Station 79
#  - Accident 5926 handled by Station 22
#  - Accident 5927 handled by Station 65
#  - Accident 5928 handled by Station 92
#  - Accident 5929 handled by Station 65
#  - Accident 5930 handled by Station 37
#  - Accident 5931 handled by Station 28
#  - Accident 5932 handled by Station 28
#  - Accident 5933 handled by Station 35
#  - Accident 5934 handled by Station 20
#  - Accident 5935 handled by Station 99
#  - Accident 5936 handled by Station 98
#  - Accident 5937 handled by Station 35
#  - Accident 5938 handled by Station 35
#  - Accident 5939 handled by Station 82
#  - Accident 5940 handled by Station 57
#  - Accident 5941 handled by Station 24
#  - Accident 5942 handled by Station 7
#  - Accident 5943 handled by Station 35
#  - Accident 5944 handled by Station 36
#  - Accident 5945 handled by Station 16
#  - Accident 5946 handled by Station 60
#  - Accident 5947 handled by Station 82
#  - Accident 5948 handled by Station 24
#  - Accident 5949 handled by Station 60
#  - Accident 5950 handled by Station 89
#  - Accident 5951 handled by Station 89
#  - Accident 5952 handled by Station 57
#  - Accident 5953 handled by Station 53
#  - Accident 5954 handled by Station 82
#  - Accident 5955 handled by Station 22
#  - Accident 5956 handled by Station 84
#  - Accident 5957 handled by Station 51
#  - Accident 5958 handled by Station 87
#  - Accident 5959 handled by Station 53
#  - Accident 5960 handled by Station 69
#  - Accident 5961 handled by Station 72
#  - Accident 5962 handled by Station 0
#  - Accident 5963 handled by Station 70
#  - Accident 5964 handled by Station 87
#  - Accident 5965 handled by Station 92
#  - Accident 5966 handled by Station 60
#  - Accident 5967 handled by Station 97
#  - Accident 5968 handled by Station 22
#  - Accident 5969 handled by Station 22
#  - Accident 5970 handled by Station 22
#  - Accident 5971 handled by Station 22
#  - Accident 5972 handled by Station 22
#  - Accident 5973 handled by Station 22
#  - Accident 5974 handled by Station 22
#  - Accident 5975 handled by Station 72
#  - Accident 5976 handled by Station 6
#  - Accident 5977 handled by Station 85
#  - Accident 5978 handled by Station 57
#  - Accident 5979 handled by Station 14
#  - Accident 5980 handled by Station 99
#  - Accident 5981 handled by Station 66
#  - Accident 5982 handled by Station 4
#  - Accident 5983 handled by Station 59
#  - Accident 5984 handled by Station 59
#  - Accident 5985 handled by Station 36
#  - Accident 5986 handled by Station 36
#  - Accident 5987 handled by Station 58
#  - Accident 5988 handled by Station 4
#  - Accident 5989 handled by Station 4
#  - Accident 5990 handled by Station 58
#  - Accident 5991 handled by Station 58
#  - Accident 5992 handled by Station 4
#  - Accident 5993 handled by Station 4
#  - Accident 5994 handled by Station 92
#  - Accident 5995 handled by Station 25
#  - Accident 5996 handled by Station 25
#  - Accident 5997 handled by Station 57
#  - Accident 5998 handled by Station 65
#  - Accident 5999 handled by Station 41
#  - Accident 6000 handled by Station 41
#  - Accident 6001 handled by Station 43
#  - Accident 6002 handled by Station 22
#  - Accident 6003 handled by Station 69
#  - Accident 6004 handled by Station 7
#  - Accident 6005 handled by Station 90
#  - Accident 6006 handled by Station 7
#  - Accident 6007 handled by Station 7
#  - Accident 6008 handled by Station 7
#  - Accident 6009 handled by Station 7
#  - Accident 6010 handled by Station 7
#  - Accident 6011 handled by Station 7
#  - Accident 6012 handled by Station 7
#  - Accident 6013 handled by Station 17
#  - Accident 6014 handled by Station 40
#  - Accident 6015 handled by Station 78
#  - Accident 6016 handled by Station 78
#  - Accident 6017 handled by Station 5
#  - Accident 6018 handled by Station 23
#  - Accident 6019 handled by Station 23
#  - Accident 6020 handled by Station 23
#  - Accident 6021 handled by Station 23
#  - Accident 6022 handled by Station 99
#  - Accident 6023 handled by Station 23
#  - Accident 6024 handled by Station 56
#  - Accident 6025 handled by Station 22
#  - Accident 6026 handled by Station 86
#  - Accident 6027 handled by Station 25
#  - Accident 6028 handled by Station 79
#  - Accident 6029 handled by Station 92
#  - Accident 6030 handled by Station 60
#  - Accident 6031 handled by Station 78
#  - Accident 6032 handled by Station 50
#  - Accident 6033 handled by Station 89
#  - Accident 6034 handled by Station 79
#  - Accident 6035 handled by Station 92
#  - Accident 6036 handled by Station 56
#  - Accident 6037 handled by Station 63
#  - Accident 6038 handled by Station 2
#  - Accident 6039 handled by Station 51
#  - Accident 6040 handled by Station 63
#  - Accident 6041 handled by Station 63
#  - Accident 6042 handled by Station 63
#  - Accident 6043 handled by Station 63
#  - Accident 6044 handled by Station 63
#  - Accident 6045 handled by Station 59
#  - Accident 6046 handled by Station 56
#  - Accident 6047 handled by Station 83
#  - Accident 6048 handled by Station 83
#  - Accident 6049 handled by Station 89
#  - Accident 6050 handled by Station 6
#  - Accident 6051 handled by Station 22
#  - Accident 6052 handled by Station 6
#  - Accident 6053 handled by Station 42
#  - Accident 6054 handled by Station 39
#  - Accident 6055 handled by Station 39
#  - Accident 6056 handled by Station 90
#  - Accident 6057 handled by Station 89
#  - Accident 6058 handled by Station 0
#  - Accident 6059 handled by Station 35
#  - Accident 6060 handled by Station 35
#  - Accident 6061 handled by Station 0
#  - Accident 6062 handled by Station 35
#  - Accident 6063 handled by Station 0
#  - Accident 6064 handled by Station 6
#  - Accident 6065 handled by Station 37
#  - Accident 6066 handled by Station 57
#  - Accident 6067 handled by Station 37
#  - Accident 6068 handled by Station 89
#  - Accident 6069 handled by Station 88
#  - Accident 6070 handled by Station 88
#  - Accident 6071 handled by Station 22
#  - Accident 6072 handled by Station 89
#  - Accident 6073 handled by Station 21
#  - Accident 6074 handled by Station 24
#  - Accident 6075 handled by Station 72
#  - Accident 6076 handled by Station 72
#  - Accident 6077 handled by Station 0
#  - Accident 6078 handled by Station 0
#  - Accident 6079 handled by Station 0
#  - Accident 6080 handled by Station 89
#  - Accident 6081 handled by Station 89
#  - Accident 6082 handled by Station 89
#  - Accident 6083 handled by Station 35
#  - Accident 6084 handled by Station 56
#  - Accident 6085 handled by Station 78
#  - Accident 6086 handled by Station 83
#  - Accident 6087 handled by Station 62
#  - Accident 6088 handled by Station 6
#  - Accident 6089 handled by Station 83
#  - Accident 6090 handled by Station 92
#  - Accident 6091 handled by Station 92
#  - Accident 6092 handled by Station 16
#  - Accident 6093 handled by Station 50
#  - Accident 6094 handled by Station 44
#  - Accident 6095 handled by Station 0
#  - Accident 6096 handled by Station 0
#  - Accident 6097 handled by Station 25
#  - Accident 6098 handled by Station 25
#  - Accident 6099 handled by Station 14
#  - Accident 6100 handled by Station 53
#  - Accident 6101 handled by Station 81
#  - Accident 6102 handled by Station 22
#  - Accident 6103 handled by Station 37
#  - Accident 6104 handled by Station 63
#  - Accident 6105 handled by Station 44
#  - Accident 6106 handled by Station 21
#  - Accident 6107 handled by Station 84
#  - Accident 6108 handled by Station 84
#  - Accident 6109 handled by Station 57
#  - Accident 6110 handled by Station 81
#  - Accident 6111 handled by Station 22
#  - Accident 6112 handled by Station 65
#  - Accident 6113 handled by Station 79
#  - Accident 6114 handled by Station 79
#  - Accident 6115 handled by Station 98
#  - Accident 6116 handled by Station 44
#  - Accident 6117 handled by Station 14
#  - Accident 6118 handled by Station 42
#  - Accident 6119 handled by Station 65
#  - Accident 6120 handled by Station 5
#  - Accident 6121 handled by Station 89
#  - Accident 6122 handled by Station 35
#  - Accident 6123 handled by Station 54
#  - Accident 6124 handled by Station 54
#  - Accident 6125 handled by Station 51
#  - Accident 6126 handled by Station 65
#  - Accident 6127 handled by Station 87
#  - Accident 6128 handled by Station 38
#  - Accident 6129 handled by Station 66
#  - Accident 6130 handled by Station 36
#  - Accident 6131 handled by Station 93
#  - Accident 6132 handled by Station 79
#  - Accident 6133 handled by Station 41
#  - Accident 6134 handled by Station 99
#  - Accident 6135 handled by Station 2
#  - Accident 6136 handled by Station 41
#  - Accident 6137 handled by Station 41
#  - Accident 6138 handled by Station 2
#  - Accident 6139 handled by Station 41
#  - Accident 6140 handled by Station 73
#  - Accident 6141 handled by Station 2
#  - Accident 6142 handled by Station 73
#  - Accident 6143 handled by Station 73
#  - Accident 6144 handled by Station 98
#  - Accident 6145 handled by Station 2
#  - Accident 6146 handled by Station 73
#  - Accident 6147 handled by Station 73
#  - Accident 6148 handled by Station 5
#  - Accident 6149 handled by Station 2
#  - Accident 6150 handled by Station 41
#  - Accident 6151 handled by Station 41
#  - Accident 6152 handled by Station 41
#  - Accident 6153 handled by Station 44
#  - Accident 6154 handled by Station 73
#  - Accident 6155 handled by Station 2
#  - Accident 6156 handled by Station 2
#  - Accident 6157 handled by Station 57
#  - Accident 6158 handled by Station 41
#  - Accident 6159 handled by Station 2
#  - Accident 6160 handled by Station 41
#  - Accident 6161 handled by Station 44
#  - Accident 6162 handled by Station 41
#  - Accident 6163 handled by Station 16
#  - Accident 6164 handled by Station 41
#  - Accident 6165 handled by Station 41
#  - Accident 6166 handled by Station 66
#  - Accident 6167 handled by Station 23
#  - Accident 6168 handled by Station 66
#  - Accident 6169 handled by Station 41
#  - Accident 6170 handled by Station 36
#  - Accident 6171 handled by Station 39
#  - Accident 6172 handled by Station 81
#  - Accident 6173 handled by Station 35
#  - Accident 6174 handled by Station 45
#  - Accident 6175 handled by Station 22
#  - Accident 6176 handled by Station 92
#  - Accident 6177 handled by Station 70
#  - Accident 6178 handled by Station 60
#  - Accident 6179 handled by Station 58
#  - Accident 6180 handled by Station 78
#  - Accident 6181 handled by Station 42
#  - Accident 6182 handled by Station 40
#  - Accident 6183 handled by Station 40
#  - Accident 6184 handled by Station 66
#  - Accident 6185 handled by Station 45
#  - Accident 6186 handled by Station 25
#  - Accident 6187 handled by Station 60
#  - Accident 6188 handled by Station 60
#  - Accident 6189 handled by Station 60
#  - Accident 6190 handled by Station 81
#  - Accident 6191 handled by Station 17
#  - Accident 6192 handled by Station 17
#  - Accident 6193 handled by Station 89
#  - Accident 6194 handled by Station 21
#  - Accident 6195 handled by Station 25
#  - Accident 6196 handled by Station 41
#  - Accident 6197 handled by Station 16
#  - Accident 6198 handled by Station 86
#  - Accident 6199 handled by Station 63
#  - Accident 6200 handled by Station 63
#  - Accident 6201 handled by Station 63
#  - Accident 6202 handled by Station 97
#  - Accident 6203 handled by Station 43
#  - Accident 6204 handled by Station 43
#  - Accident 6205 handled by Station 43
#  - Accident 6206 handled by Station 59
#  - Accident 6207 handled by Station 43
#  - Accident 6208 handled by Station 4
#  - Accident 6209 handled by Station 59
#  - Accident 6210 handled by Station 99
#  - Accident 6211 handled by Station 85
#  - Accident 6212 handled by Station 78
#  - Accident 6213 handled by Station 15
#  - Accident 6214 handled by Station 62
#  - Accident 6215 handled by Station 45
#  - Accident 6216 handled by Station 35
#  - Accident 6217 handled by Station 22
#  - Accident 6218 handled by Station 23
#  - Accident 6219 handled by Station 31
#  - Accident 6220 handled by Station 31
#  - Accident 6221 handled by Station 31
#  - Accident 6222 handled by Station 31
#  - Accident 6223 handled by Station 90
#  - Accident 6224 handled by Station 21
#  - Accident 6225 handled by Station 61
#  - Accident 6226 handled by Station 15
#  - Accident 6227 handled by Station 84
#  - Accident 6228 handled by Station 84
#  - Accident 6229 handled by Station 90
#  - Accident 6230 handled by Station 90
#  - Accident 6231 handled by Station 22
#  - Accident 6232 handled by Station 57
#  - Accident 6233 handled by Station 57
#  - Accident 6234 handled by Station 14
#  - Accident 6235 handled by Station 24
#  - Accident 6236 handled by Station 24
#  - Accident 6237 handled by Station 72
#  - Accident 6238 handled by Station 79
#  - Accident 6239 handled by Station 79
#  - Accident 6240 handled by Station 88
#  - Accident 6241 handled by Station 27
#  - Accident 6242 handled by Station 0
#  - Accident 6243 handled by Station 25
#  - Accident 6244 handled by Station 24
#  - Accident 6245 handled by Station 23
#  - Accident 6246 handled by Station 24
#  - Accident 6247 handled by Station 23
#  - Accident 6248 handled by Station 0
#  - Accident 6249 handled by Station 31
#  - Accident 6250 handled by Station 0
#  - Accident 6251 handled by Station 43
#  - Accident 6252 handled by Station 92
#  - Accident 6253 handled by Station 63
#  - Accident 6254 handled by Station 93
#  - Accident 6255 handled by Station 62
#  - Accident 6256 handled by Station 62
#  - Accident 6257 handled by Station 62
#  - Accident 6258 handled by Station 71
#  - Accident 6259 handled by Station 90
#  - Accident 6260 handled by Station 88
#  - Accident 6261 handled by Station 87
#  - Accident 6262 handled by Station 16
#  - Accident 6263 handled by Station 70
#  - Accident 6264 handled by Station 16
#  - Accident 6265 handled by Station 65
#  - Accident 6266 handled by Station 65
#  - Accident 6267 handled by Station 81
#  - Accident 6268 handled by Station 16
#  - Accident 6269 handled by Station 16
#  - Accident 6270 handled by Station 87
#  - Accident 6271 handled by Station 84
#  - Accident 6272 handled by Station 65
#  - Accident 6273 handled by Station 84
#  - Accident 6274 handled by Station 51
#  - Accident 6275 handled by Station 27
#  - Accident 6276 handled by Station 72
#  - Accident 6277 handled by Station 19
#  - Accident 6278 handled by Station 32
#  - Accident 6279 handled by Station 31
#  - Accident 6280 handled by Station 62
#  - Accident 6281 handled by Station 21
#  - Accident 6282 handled by Station 60
#  - Accident 6283 handled by Station 22
#  - Accident 6284 handled by Station 24
#  - Accident 6285 handled by Station 24
#  - Accident 6286 handled by Station 50
#  - Accident 6287 handled by Station 14
#  - Accident 6288 handled by Station 25
#  - Accident 6289 handled by Station 82
#  - Accident 6290 handled by Station 3
#  - Accident 6291 handled by Station 99
#  - Accident 6292 handled by Station 93
#  - Accident 6293 handled by Station 6
#  - Accident 6294 handled by Station 58
#  - Accident 6295 handled by Station 93
#  - Accident 6296 handled by Station 77
#  - Accident 6297 handled by Station 42
#  - Accident 6298 handled by Station 50
#  - Accident 6299 handled by Station 23
#  - Accident 6300 handled by Station 21
#  - Accident 6301 handled by Station 79
#  - Accident 6302 handled by Station 36
#  - Accident 6303 handled by Station 15
#  - Accident 6304 handled by Station 0
#  - Accident 6305 handled by Station 35
#  - Accident 6306 handled by Station 63
#  - Accident 6307 handled by Station 80
#  - Accident 6308 handled by Station 51
#  - Accident 6309 handled by Station 51
#  - Accident 6310 handled by Station 60
#  - Accident 6311 handled by Station 15
#  - Accident 6312 handled by Station 93
#  - Accident 6313 handled by Station 80
#  - Accident 6314 handled by Station 5
#  - Accident 6315 handled by Station 89
#  - Accident 6316 handled by Station 42
#  - Accident 6317 handled by Station 31

# %%
import folium
from folium.plugins import MarkerCluster

# Initialize map centered around average accident location
avg_lat = accident_df['latitude'].mean()
avg_lon = accident_df['longitude'].mean()
m = folium.Map(location=[avg_lat, avg_lon], zoom_start=12)

# Add Accident Points
accident_cluster = MarkerCluster(name="Accidents").add_to(m)
for idx, row in accident_df.iterrows():
    folium.CircleMarker(
        location=[row['latitude'], row['longitude']],
        radius=3,
        color='red',
        fill=True,
        fill_opacity=0.6
    ).add_to(accident_cluster)

# Add Ambulance Stations
for i, (lat, lon) in enumerate(station_coords):
    if x[i].varValue == 1:
        folium.Marker(
            location=[lat, lon],
            icon=folium.Icon(color='blue', icon='plus-sign', prefix='glyphicon'),
            popup=f"Ambulance Station {i}"
        ).add_to(m)

# Optional: Draw lines showing assignment=
for j in range(num_accidents):
    for i in range(len(station_coords)):
        if y[(i, j)].varValue == 1:
            acc_lat, acc_lon = accident_coords[j]
            stat_lat, stat_lon = station_coords[i]
            folium.PolyLine(
                locations=[[stat_lat, stat_lon], [acc_lat, acc_lon]],
                color='gray',
                weight=1,
                opacity=0.5
            ).add_to(m)

# Add Layer Control
folium.LayerControl().add_to(m)

# Show map
m.save("ambulance_optimization_map.html")
print(" Map saved as 'ambulance_optimization_map.html'")
# Out:
#  Map saved as 'ambulance_optimization_map.html'
